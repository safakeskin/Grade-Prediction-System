# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
sentence = """At eight o'clock on Thursday morning Arthur didn't feel very good."""

# %%
tokens = nltk.word_tokenize(sentence)
tokens
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-3-13c0deaefe09> in <module>()
# ----> 1 tokens = nltk.word_tokenize(sentence)
#       2 tokens
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     141     :type preserve_line: bool
#     142     """
# --> 143     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     144     return [
#     145         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     102     :param language: the model name in the Punkt corpus
#     103     """
# --> 104     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
#     105     return tokenizer.tokenize(text)
#     106
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/nltk/data.py in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     866
#     867     # Load the resource.
# --> 868     opened_resource = _open(resource_url)
#     869
#     870     if format == 'raw':
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/nltk/data.py in _open(resource_url)
#     991
#     992     if protocol is None or protocol.lower() == 'nltk':
# --> 993         return find(path_, path + ['']).open()
#     994     elif protocol.lower() == 'file':
#     995         # urllib might not use mode='rb', so handle this one ourselves:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/nltk/data.py in find(resource_name, paths)
#     697     sep = '*' * 70
#     698     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 699     raise LookupError(resource_not_found)
#     700
#     701
#
# LookupError:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   Attempted to load tokenizers/punkt/PY3/english.pickle
#
#   Searched in:
#     - '/Users/tugba/nltk_data'
#     - '/Library/Frameworks/Python.framework/Versions/3.5/nltk_data'
#     - '/Library/Frameworks/Python.framework/Versions/3.5/share/nltk_data'
#     - '/Library/Frameworks/Python.framework/Versions/3.5/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - ''
# **********************************************************************
